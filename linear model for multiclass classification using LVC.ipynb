# %%
import mglearn
import matplotlib.pyplot as plt
from sklearn.svm import LinearSVC
import numpy as np
# %matplotlib inline

# %%
X,y = mglearn.datasets.make_blobs(random_state=42)

# %%
mglearn.discrete_scatter(X[:,0],X[:,1],y)
plt.xlabel("Feature 0")
plt.ylabel("Feature 1")
plt.legend(["Class 0","Class 1","Class 2"])

# %%
linear_svc = LinearSVC()
linear_svc.fit(X,y)
print(linear_svc.coef_.shape)
print(linear_svc.intercept_.shape)
# Out:
# (3, 2)
# (3,)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(

# %%
mglearn.discrete_scatter(X[:,0],X[:,1],y)
line = np.linspace(-15,15)
for coef,intercept,color in zip(linear_svc.coef_,linear_svc.intercept_,mglearn.cm3.colors):
    plt.plot(line,-(line*coef[0] + intercept)/coef[1],c=color)
plt.ylim(-10,15)
plt.xlim(-10,8)
plt.xlabel("Feature 0")
plt.ylabel("Feature 1")
plt.legend(["Class 0","Class 1","Class 2"])

# %%
mglearn.discrete_scatter(X[:,0],X[:,1],y)
mglearn.plots.plot_2d_classification(linear_svc,X,alpha=.5,fill=True)
line = np.linspace(-15,15)
for coef,intercept,color in zip(linear_svc.coef_,linear_svc.intercept_,mglearn.cm3.colors):
    plt.plot(line,-(line*coef[0] + intercept)/coef[1],c=color)
plt.ylim(-10,15)
plt.xlim(-10,8)
plt.xlabel("Feature 0")
plt.ylabel("Feature 1")
plt.legend(["Class 0","Class 1","Class 2"])
